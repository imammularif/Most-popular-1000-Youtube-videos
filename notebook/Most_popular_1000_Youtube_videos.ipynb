# %%
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from matplotlib.ticker import FuncFormatter

# %%
file_name = "Most popular 1000 Youtube videos.csv"

# %%
# Baca file
df = pd.read_csv(file_name)

# %%
# Bersihkan angka dari koma dan ubah ke float
for col in ['Video views', 'Likes', 'Dislikes']:
    df[col] = df[col].replace({',': ''}, regex=True).astype(float)

# %% [markdown]
# TOTAL VIEW, LIKES, DISLIKES, & JUMLAH RANK

# %%
# Hitung total
total_views = df['Video views'].sum()
total_likes = df['Likes'].sum()
total_dislikes = df['Dislikes'].sum()
total_rank = len(df)

# Print hasil
print(f"Total Views: {total_views:,.0f}")
print(f"Total Likes: {total_likes:,.0f}")
print(f"Total Dislikes: {total_dislikes:,.0f}")
print(f"Total Rank (Data): {total_rank:,}")
# Out:
# Total Views: 24,534,345,791
# Total Likes: 368,545,103
# Total Dislikes: 1,223,865
# Total Rank (Data): 1,000

# %% [markdown]
# MENAMPILKAN RANK, VIDIO, LIKES, DISLIKES, VIDIO VIEWS, & PUBLISHED

# %%
cols = ['rank', 'Video', 'Likes', 'Dislikes', 'Video views', 'published']
df_clean = df[cols]

df_clean.head(10)
# Out:
#    rank                                              Video       Likes  \
# 0     1  Lil Nas X - Old Town Road (Official Movie) ft....   3497955.0
# 1     2  20 Tennis shots if they were not filmed, NOBOD...     19023.0
# 2     3                 JoJo Siwa - Karma (Official Video)    293563.0
# 3     4    David Kushner - Daylight (Official Music Video)    680732.0
# 4     5  Wiz Khalifa - See You Again ft. Charlie Puth [...  44428537.0
# 5     6  JP Saxe - If the World Was Ending (Official Vi...    804353.0
# 6     7                  JENNIE - ZEN (RUBY ALBUM MARCH 7)   1261577.0
# 7     8  Polo G, Stunna 4 Vegas & NLE Choppa feat. Mike...    320910.0
# 8     9  Yovie Widianto, Lyodra, Tiara Andini, Ziva Mag...    452087.0
# 9    10                JD Pantoja - 12•19 (Official Video)   1027392.0
#
#    Dislikes   Video views  published
# 0   78799.0  5.407168e+07       2019
# 1     859.0  3.471237e+06       2017
# 2       NaN  3.420675e+07       2024
# ...

# %% [markdown]
# Urutkan dari yang TERBANYAK views (top 10)

# %%
top10 = df_clean.sort_values(by='Video views', ascending=False).head(10)
print("10 Video dengan Views Terbanyak")
display(top10)
# Out:
# 10 Video dengan Views Terbanyak
#      rank                                              Video       Likes  \
# 4       5  Wiz Khalifa - See You Again ft. Charlie Puth [...  44428537.0
# 60     61  Pedro Capó, Farruko - Calma (Remix - Official ...  13755637.0
# 381   382  Jhay Cortez, J. Balvin, Bad Bunny - No Me Cono...   6622023.0
# 136   137  ROSALÍA, J Balvin - Con Altura (Official Video...   9768545.0
# 31     32        6ix9ine - FEFE ft. Nicki Minaj, Murda Beatz   9015394.0
# 142   143  Rocket Blast Off #messingaround #flying #fun #...   1868300.0
# 420   421   The emergency rescue dog is so awesome...cutepet   1759120.0
# 131   132  Drawing the pillar of life🥶🗿#trollface #trollf...   3173002.0
# 192   193  A disabled duckling helps his cat friend 🐥 #Du...   3749872.0
# 278   279                           0 Sharpness knife test?💀   4702361.0
#
#      Dislikes   Video views  published
# 4         NaN  6.547981e+09       2015
# 60        NaN  2.964195e+09       2018
# ...

# %% [markdown]
# Urutkan dari yang TERENDAH views (bottom 10)

# %%
bottom10 = df_clean.sort_values(by='Video views', ascending=True).head(10)
print("10 Video dengan Views Terendah")
display(bottom10)
# Out:
# 10 Video dengan Views Terendah
#      rank                                              Video    Likes  \
# 778   779  Biometrids Decentralised and Anonymous ID by F...   6760.0
# 10     11  Power Star Pawan Kalyan Special Surprise To Se...   1007.0
# 674   675                        Eddy Court - Scoop & Boolin   1011.0
# 451   452  Music Marketing & Promotion. Dominate Digital ...   8370.0
# 883   884                KIKESA - À ma place (Clip Officiel)  12693.0
# 763   764                     مهرجان بريدة للتمور 1438 هجرية   1590.0
# 872   873                 Gazo, Tiakola - 24/34 (Visualizer)  10509.0
# 454   455                        Гимн Украины Крым Ялта 2K17   1963.0
# 954   955         S.Pri Noir - 7 vies (Clip Officiel) ft. RK  13026.0
# 847   848  Mous-K - On part à la guerre (Clip officiel) f...   8778.0
#
#      Dislikes  Video views  published
# 778      81.0      44939.0       2018
# 10       82.0      96686.0       2018
# 674       5.0     116227.0       2017
# ...

# %% [markdown]
# DONUTS CHAR

# %%
# --- Hitung jumlah tiap kategori
category_counts = df['Category'].value_counts()

# %%
# --- Hitung persentase
percentages = (category_counts / category_counts.sum()) * 100

# %%
# --- Warna opsional (biar mirip kayak contoh)
colors = ['#4e79a7', '#f28e2b', '#e15759', '#76b7b2', '#bab0ac']

# %%
# --- Ambil top 5 + “Lainnya”
top5 = category_counts.head(5)
others = pd.Series({'Lainnya': category_counts.iloc[5:].sum()})
final_category = pd.concat([top5, others])

# --- Deskripsi kategori
category_desc = {
    'Music': 'Musik & konser',
    'Entertainment': 'Hiburan & film',
    'People & Blogs': 'Vlog & cerita pribadi',
    'Comedy': 'Konten lucu/parodi',
    'Gaming': 'Game & streaming',
    'Lainnya': 'Kategori kecil lainnya'
}

# --- DataFrame
cat_df = pd.DataFrame({
    'Category': final_category.index,
    'Count': final_category.values
})
cat_df['Deskripsi'] = cat_df['Category'].map(category_desc)

# --- Warna lembut dashboard
colors = ['#4e79a7', '#f28e2b', '#e15759', '#76b7b2', '#59a14f', '#bab0ac']

# --- Chart
fig = go.Figure()

fig.add_trace(go.Pie(
    labels=cat_df['Category'],
    values=cat_df['Count'],
    hole=0.55,
    marker=dict(colors=colors, line=dict(color='white', width=1)),
    textinfo='percent+label',
    textposition='outside',
    showlegend=False
))

# --- bullet text
annotations = []
y_pos = 0.85
for i, row in enumerate(cat_df.itertuples()):
    annotations.append(dict(
        x=1.20,  # posisi kanan chart
        y=y_pos - i*0.15,  # jarak antar baris
        xanchor='left',
        text=f"<b><span style='color:{colors[i]}'>⬤</span> {row.Category}</b><br><span style='font-size:11px;color:#555;'>{row.Deskripsi}</span>",
        showarrow=False,
        align='left'
    ))

# --- Layout
fig.update_layout(
    width=750,
    height=600,
    margin=dict(t=80, b=40, l=40, r=250),
    annotations=annotations,
    paper_bgcolor='white',
    plot_bgcolor='white',
    title_text='Category menurut Record Count',
    title_font=dict(size=18, family='Arial Black'),
)


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# --- Get Column ---
df = df[['rank', 'Video views']].dropna()
df['Video views'] = pd.to_numeric(df['Video views'], errors='coerce')

# %% [markdown]
# BAR CHART

# %%
# --- Ambil 5 teratas berdasarkan views ---
top5 = df.nlargest(5, 'Video views')

# --- Format angka jadi jutaan (misal 6.547.981.039 → 6.5 B) ---
def format_milions(x, pos):
    if x >= 1e9:
        return f'{x/1e9:.1f} B'
    elif x >= 1e6:
        return f'{x/1e6:.1f} M'
    return int(x)

# --- Warna biru ---
color = '#4285F4'

# --- Layout ---
fig, ax = plt.subplots(figsize=(7, 6))
bars = ax.barh(top5['rank'].astype(str), top5['Video views'], color=color, height=0.5)

# --- Tambah label di batangnya (selalu tampil) ---
for bar in bars:
    value = bar.get_width()
    label = f"{value:,.0f}"

    # kalau batangnya pendek → teks di luar
    if value < top5['Video views'].max() * 0.2:
        ax.text(value + (value * 0.01), bar.get_y() + bar.get_height()/2,
                label, ha='left', va='center', color='black',
                fontsize=9, fontweight='bold')
    else:
        # batang cukup panjang → teks di dalam
        ax.text(value - (value * 0.02), bar.get_y() + bar.get_height()/2,
                label, ha='right', va='center', color='white',
                fontsize=9, fontweight='bold')

# --- Styling chart ---
ax.set_title('Video views menurut rank', fontsize=14, fontweight='bold', pad=15)
ax.set_xlabel('Video views', fontsize=11)
ax.set_ylabel('rank', fontsize=11)
ax.xaxis.set_major_formatter(FuncFormatter(format_milions))
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# --- Border oranye ---
for spine in ax.spines.values():
    spine.set_edgecolor('#f28e2b')
    spine.set_linewidth(2)

plt.tight_layout(pad=2)
plt.show()
